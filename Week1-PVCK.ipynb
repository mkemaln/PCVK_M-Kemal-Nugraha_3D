# %% [markdown]
# <a href="https://colab.research.google.com/github/mkemaln/PCVK_M-Kemal-Nugraha_3D/blob/main/Week1-PVCK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Langkah 1
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io, transform
from PIL import Image
import matplotlib.pylab as plt

# %%
# @title Langkah 2
# Membuat list untuk menyimpan image url
urls = [
    "https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
    "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
    "https://th.bing.com/th/id/OIP.d6gvMvD1wBqXXGFU3nA4xAHaFS?rs=1&pid=ImgDetMain"
]

# Baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url) # read image
  image = cv.resize(image, (0, 0), fx=0.5, fy=0.5) # resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB) # convert color to rgb
  final_frame = cv.hconcat((image, image_2)) # concat image
  cv2_imshow(final_frame) # showing image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=474x169>

# %%
# @title Langkah 3
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar =", tinggi, "x", lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar = 169 x 237
# <PIL.Image.Image image mode=RGB size=237x169>

# %%
# @title Langkah 4
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat garis horizontal di tengah gambar
for y in range(lebar):
  image_3[int(tinggi/2), y] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=474x169>

# %% [markdown]
# #**Pertanyaan**
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
# ```
# image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
# ```
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
# 4. Perhatikan potongan kode progam berikut :
# ```
# # membuat garis horizontal ditengah image
# for y in range(lebar):
#   image_3[int((tinggi)/2), y] = [255, 255, 255]
# ```
# Apakah kegunaan kode [255,255,255] ? Jelaskan!
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!

# %% [markdown]
# # **Jawaban**
# 1. Karena google colab cocok untuk pembelajaran menggunakan pyhton, karena tidak digunakannya hardware/ resource sendiri untuk mengeksekusi maupun menyimpan hasil kode pyhton.
# 2.
# *   numpy : library ini adalah library dasar untuk melakukan komputasi numerik seperti operasi matematik, aljabar linear, statistik, array, array multidimensi.
# *   pandas : biasa digunakan untuk pemrosesan manupulasi data dan analisis data.
# *   cv2 : digunakan untuk pengolahan gambar dan video dengan berbagai fungsi, seperti pengenalan objek, pemrosesan video.
# *   skimage : bisa digunakan untuk pengolahan gambar, seperti manipulasi gambar. mengubah ukuran, memfilter.
# *   matplotlib : digunakan untuk memvisualisasi data dalam bentuk berbagai grafik.
#
# * Pada modul praktikum ini hanya dipakai 2 library yaitu cv2 dan skimage
#
# 3. Kode tersebut berguna untuk mengatur ulang ukuran gambar menjadi setengahnya. Apabila kode itu tidak dilakukan, maka gambar akan ditampilakan dengan ukuran asli.
#
# 4. Untuk menampilkan garis putih pada gambar.
# ```
# int((tinggi)/2), y
# ```
# potongan kode tersebut berguna untuk mengatur peletakan garis, yaitu pada tinggi/2 atau pada tengah gambar (secara vertikal).
# ```
# [255, 255, 255]
# ```
# dan ini adalah kode warna BGR putih, maka dari itu yang ditampilkan garis berwarna putih.
#
# 5. Semakin tinggi resolusi atau detail gambar tersebut, semakin banyak pixel didalamnya. Dan juga semakin besar pula ukuran file tersebut. Resolusi yang lebih rendah akan berlaku kebalikannya.

# %%
# @title Tugas 1 - Vertical Line
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat garis vertikal di tengah gambar
for x in range(tinggi):
  image_3[x, int(lebar/2)] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=474x169>

# %%
# @title Tugas 2 - Cross Diagonal Line
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat garis cross di gambar
for x in range(lebar):
  y = int(x * (tinggi / lebar))
  image_3[y, x] = [255, 255, 255]

for a in range(lebar):
  b = int((lebar - a - 1) * (tinggi / lebar))
  image_3[b,a]=[255,255,255]

final_frame2 = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame2)
# Out:
# <PIL.Image.Image image mode=RGB size=474x169>

# %%
# @title Tugas 3 - Line with Desired Length
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat garis horizontal dengan inputan awal
start = 65    # dimulainya garis
end = 100      # berakhirnya garis
for y in range(start,end):
  image_3[int(tinggi/2), y] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=474x169>

# %%
# @title Tugas 3 - Line with Desired Length
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat garis horizontal yang bisa ditentukan start dan end point (30 sebagai start, 120 sebagai end)
cv.line(image_3, (30, int(tinggi/2)), (120, int(tinggi/2)), [255, 255, 255], 1)

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=474x169>

# %%
# @title Tugas 4 - Rectangle in Randomized Place
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# input peletakkan x dan y secara random
x = np.random.randint(10)               # maks random hingga 10
y = np.random.randint(10)               # maks random hingga 10

# Membuat garis horizontal secara random
cv.rectangle(image_3, (int(lebar/x)-20, int(tinggi/y)-20), (int(lebar/x)+20, int(tinggi/y)+20), [255, 255, 255], -1)

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=474x169>

# %%
# @title Tugas Kelompok
# Membuat list untuk menyimpan image url
url = "https://th.bing.com/th/id/R.23c30498e2d19affbd55a44476ecfc99?rik=QP2dZ%2b%2f02Qe0Bw&riu=http%3a%2f%2f1.bp.blogspot.com%2f-0pkJMBmW2bA%2fU7PGF1Jy0jI%2fAAAAAAAAAH0%2fSSSIOLAfacw%2fs1600%2fktp-jokowi.jpg&ehk=2RfHd3sxi0Dr6CBf4Xyul8jnBBHJEmmFbhoAkgHIY%2b4%3d&risl=&pid=ImgRaw&r=0&sres=1&sresct=1"

# Baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
ktp = io.imread(url) # read image
ktp = cv.resize(ktp, (0, 0), fx=0.5, fy=0.5) # resize image to half size
ktp_2 = cv.cvtColor(ktp, cv.COLOR_BGR2RGB) # convert color to rgb
tinggi_ktp = ktp_2.shape[0]
lebar_ktp = ktp_2.shape[1]
cv2_imshow(ktp_2) # showing image
# Out:
# <PIL.Image.Image image mode=RGB size=621x400>

# %%
# Sensor Mata
for y in range(430,532):
  for x in range(160,170):
    ktp_2[x, y] = [0,0,0]

# Sensor NIK
for y in range(165,400):
  for x in range(78,100):
    ktp_2[x, y] = [0,0,255]

cv2_imshow(ktp_2)
# Out:
# <PIL.Image.Image image mode=RGB size=621x400>
