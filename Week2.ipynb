# %% [markdown]
# <a href="https://colab.research.google.com/github/mkemaln/PCVK_M-Kemal-Nugraha_3D/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Mount Data from Google Drive
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# @title Processing the image
import cv2 as cv
from google.colab.patches import cv2_imshow

from skimage import io
import matplotlib.pyplot as plt

import numpy as np

img = cv.imread('/content/drive/MyDrive/cat.jpg')

plt.imshow(img)

# %%
# @title Convert to RGB
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
# @title Image processing with cv function
img_gray = cv.imread('/content/drive/MyDrive/cat.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

plt.imshow(img_gray, cmap='gray')
plt.imshow(img_gray, cmap='magma')

# %%
# @title Resizing image using cv function
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB),(512,1024))
plt.imshow(img4)

# %%
# @title Flipping image using cv function
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
# @title Membuat bentuk Geometri 2D dari OpenCV int16
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)

# font = cv.FONT_HERSHEY_SIMPLEX
# cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)

font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='kitler',org=(10,500),fontFace=font,fontScale=2,color=(255,0,0),thickness=2,lineType=cv.LINE_AA)

plt.imshow(black_img)

# %%
# @title Membuat bentuk Geometri 2D dari OpenCV int32
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int32)
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
pts = vertices.reshape((-1,1,2))
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
# @title Tugas - Code Space
# no 2
img6 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
red,green,blue = cv.split(img6)
red *= 0
merged_img = cv.merge([red,green,blue])
plt.imshow(merged_img)

# %%
# no 3
img7 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cropped_img = img7[20:116, 25:120]
plt.imshow(cropped_img)

# %%
# no 4
img8 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cropped_img = img8[5:30]
red,green,blue = cv.split(cropped_img)
green *= 0
blue *= 0
merged_img2 = cv.merge([red,green,blue])

plt.imshow(merged_img2)

# %%
# no 5
img9 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
for x in range(5):
  cv.rectangle(img9,
               pt1=(np.random.randint(400),np.random.randint(400)),
               pt2=(np.random.randint(400),np.random.randint(400)),
               color=(np.random.randint(255),np.random.randint(255),np.random.randint(255)),
               thickness=5)
  x+=1
plt.imshow(img9)
# Out:
# Resolusi image : 355 x 474
# <PIL.Image.Image image mode=RGB size=474x355>

# %%
# no 7
image = io.imread('https://th.bing.com/th/id/OIP.Yz4YKzxh4igYCPannfzkqAHaE8?rs=1&pid=ImgDetMain')
image2 = cv.cvtColor(image,cv.COLOR_BGR2RGB)
tinggi = image2.shape[0]
lebar = image2.shape[1]
print("Resolusi image :", tinggi, "x", lebar)
cv.rectangle(image2,
               pt1=(1,260),
               pt2=(50,311),
               color=(255,255,255),
               thickness=3)

cv.circle(image2,center=(200,45),radius=40,color=(0,0,255),thickness=2)
cv2_imshow(image2)
# Out:
# Resolusi image : 316 x 474
# <PIL.Image.Image image mode=RGB size=474x316>

# %%
# no 8
img10 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
tinggi = img10.shape[0]
lebar = img10.shape[1]
print("Resolusi image :", tinggi, "x", lebar)

cv.rectangle(img10,
               pt1=(1,302),
               pt2=(50,352),
               color=(255,255,255),
               thickness=3)

red,green,blue = cv.split(img10)
green *= 0
red *= 0
merged_img3 = cv.merge([red,green,blue])
# no 9
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(img10,text='kitler',org=(10,500),fontFace=font,fontScale=2,color=(255,0,0),thickness=2,lineType=cv.LINE_AA)
cv2_imshow(img10)
# Out:
# Resolusi image : 355 x 474
# <PIL.Image.Image image mode=RGB size=474x355>
